# %%
import pandas as pd

# %%
# pd.read_csv   -> enrutamos 
# delimiter=';' -> espeficamos tipo de separador
# skiprows=5    ->salteamos 5 filas
_table = pd.read_csv('c:/Users/johel/OneDrive/Escritorio/Proyecto_Analisis_Python/ventasTotales.csv', delimiter=';',skiprows=5)

# %%
# Mostramos la Tabla
_table
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 0     1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1     1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2     1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3     1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4     1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# ..         ...               ...    ...                ...          ...
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades Ganancia
# 0           6    18,00
# 1           8     3,84
# 2           3     6,30
# ...

# %%
# Metodo head -> podemos ver los primeros  5 registros
_table.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 0  1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2  1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
# Metodo head(3) -> podemos ver los 3  primeros registros
_table.head(3)
# Out:
#       Fecha          Vendedor Región          Artículo    Categoría  Unidades  \
# 0  1/1/2016      Steve Ashton  Norte  Medias Femeninas   Vestimenta         6
# 1  1/1/2016  Trevor Snodgrass  Oeste         Chocolate  Comestibles         8
# 2  1/1/2016        Sarah Bond    Sur            Gorras   Vestimenta         3
#
#   Ganancia
# 0    18,00
# 1     3,84
# 2     6,30

# %%
# Metodo tail -> Podemos ver los 5 ultimos registros
_table.tail()
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades Ganancia
# 455         6    16,50
# 456        11   115,50
# 457         4     6,40
# 458         8     6,80
# 459         7     2,10

# %%
# Metodo tail(3) -> Podemos ver los 3 ultimos registros
_table.tail(3)
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades Ganancia
# 457         4     6,40
# 458         8     6,80
# 459         7     2,10

# %%
# Obtenemos informacion de la Dataframe atraves del metodo info()
# <class 'pandas.core.frame.DataFrame'> Nos dice que es un Dataframe y no serie
# Nos describe que el indice es de 460 entradas y son desde el cero al 459
# Tiene un total de 7 columnas y dtypes: int64(1), object(6) tiene 6 registros ,tipos de datos en entero 1 y 6 de objecto

# %%
_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      460 non-null    object
#  1   Vendedor   460 non-null    object
#  2   Región     460 non-null    object
#  3   Artículo   460 non-null    object
#  4   Categoría  460 non-null    object
#  5   Unidades   460 non-null    int64
#  6   Ganancia   460 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 25.3+ KB

# %%
## Contar valores value_counts()  
## Ejemplo nombre_del dataframe.nombre_de_la_serie.value_counts()
## Ejemplo nombre_del dataframe.nombre_de_la_serie.value_counts(ascending=true)
## Ejemplo nombre_del dataframe.nombre_de_la_serie.value_counts(dropnat=true)

# %%
# Si queremos saber cuantos vendedores unicos tenemos y cuantas ventas han echo Aqui tenemos 
# un registro de 6 vendedores y al lado la cantidad de ventas
_table.Vendedor.value_counts()
# Out:
# Sarah Bond          86
# Steve Ashton        84
# Desmond Delaney     76
# Trevor Snodgrass    75
# Dustin Gee          70
# Boris Stanford      69
# Name: Vendedor, dtype: int64

# %%
# Aqui podemos ver las ventas de forma ascendiente
_table.Vendedor.value_counts(ascending=True)
# Out:
# Boris Stanford      69
# Dustin Gee          70
# Trevor Snodgrass    75
# Desmond Delaney     76
# Steve Ashton        84
# Sarah Bond          86
# Name: Vendedor, dtype: int64

# %%
# Aqui podemos ver la venta de forma descendiente
_table.Vendedor.value_counts(dropna=True)
# Out:
# Sarah Bond          86
# Steve Ashton        84
# Desmond Delaney     76
# Trevor Snodgrass    75
# Dustin Gee          70
# Boris Stanford      69
# Name: Vendedor, dtype: int64

# %%
# t_kbtq_customer_info
tabla = pd.read_csv('c:/Users/johel/OneDrive/Escritorio/Proyecto_Analisis_Python/t_kbtq_customer_info.csv', delimiter=';')

# %%
_table.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 0  1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2  1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
# al ejecutar nos listara  la columna de Vendedor por orden alfabetico
_table.Vendedor.sort_values()
# Out:
# 198      Boris Stanford
# 71       Boris Stanford
# 66       Boris Stanford
# 259      Boris Stanford
# 64       Boris Stanford
#              ...
# 212    Trevor Snodgrass
# 209    Trevor Snodgrass
# 206    Trevor Snodgrass
# 286    Trevor Snodgrass
# 459    Trevor Snodgrass
# Name: Vendedor, Length: 460, dtype: object

# %%
# Esta Sentencia no mostrara por orden de menor a mayor las columnas Vendedor y Ganancia
_table.sort_values(by=['Vendedor','Ganancia'])
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 93    6/1/2016    Boris Stanford  Norte   Chocolate  Comestibles         2
# 450  31/1/2016    Boris Stanford   Este   Chocolate  Comestibles         3
# 259  18/1/2016    Boris Stanford    Sur   Pepinillo  Comestibles         5
# 25    2/1/2016    Boris Stanford   Este         Pan  Comestibles         4
# 64    5/1/2016    Boris Stanford    Sur         Pan  Comestibles         4
# ..         ...               ...    ...         ...          ...       ...
# 231  15/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         4
# 314  21/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 328  22/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 69    5/1/2016  Trevor Snodgrass  Norte  Calcetines   Vestimenta         4
# 238  16/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         2
#
#     Ganancia
# 93      0,96
# 450     1,44
# 259     1,50
# ...

# %%
# para visualizar todas las ventas de de Articulos Gorras en la Region Norte
# aplicamos la siguiente sentencia

_table[(_table.Artículo == 'Gorras') & (_table.Región == 'Norte')]
# Out:
#          Fecha          Vendedor Región Artículo   Categoría  Unidades  \
# 85    6/1/2016        Sarah Bond  Norte   Gorras  Vestimenta         9
# 156  10/1/2016  Trevor Snodgrass  Norte   Gorras  Vestimenta         7
# 159  11/1/2016      Steve Ashton  Norte   Gorras  Vestimenta         2
# 201  14/1/2016   Desmond Delaney  Norte   Gorras  Vestimenta         5
# 360  25/1/2016      Steve Ashton  Norte   Gorras  Vestimenta         7
# 368  26/1/2016    Boris Stanford  Norte   Gorras  Vestimenta         7
# 394  27/1/2016      Steve Ashton  Norte   Gorras  Vestimenta        14
# 396  27/1/2016  Trevor Snodgrass  Norte   Gorras  Vestimenta         3
#
#     Ganancia
# 85     18,90
# 156    14,70
# 159     4,20
# 201    10,50
# 360    14,70
# 368    14,70
# 394    29,40
# 396     6,30

# %%
#  Atravez del metodo  str.contains hallamos en la columna Vendedor , palabra que contiene Boris
_table[_table.Vendedor.str.contains('Boris')]
# Out:
#          Fecha        Vendedor Región           Artículo    Categoría  \
# 6     1/1/2016  Boris Stanford  Norte          Pepinillo  Comestibles
# 11    1/1/2016  Boris Stanford  Oeste         Calcetines   Vestimenta
# 14    2/1/2016  Boris Stanford  Norte  Sánguche de Queso  Comestibles
# 20    2/1/2016  Boris Stanford   Este         Calcetines   Vestimenta
# 21    2/1/2016  Boris Stanford  Oeste            Bufanda   Vestimenta
# ..         ...             ...    ...                ...          ...
# 421  29/1/2016  Boris Stanford   Este  Sánguche de Queso  Comestibles
# 425  29/1/2016  Boris Stanford   Este         Escobillón        Hogar
# 433  30/1/2016  Boris Stanford  Norte               Soda  Comestibles
# 449  31/1/2016  Boris Stanford   Este           Sudadera   Vestimenta
# 450  31/1/2016  Boris Stanford   Este          Chocolate  Comestibles
#
#      Unidades Ganancia
# 6          14     4,20
# 11          7    15,75
# 14          8    12,80
# 20         12    27,00
# ...

# %%
# A travez de este metodo hallamos todos los que inicien con letra T con el metodo startswith('D') 
_table[_table.Vendedor.str.startswith('D')]
# Out:
#          Fecha         Vendedor Región           Artículo    Categoría  \
# 3     1/1/2016  Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4     1/1/2016  Desmond Delaney   Este          Chocolate  Comestibles
# 15    2/1/2016  Desmond Delaney  Oeste          Pepinillo  Comestibles
# 16    2/1/2016       Dustin Gee  Norte          Sandalias   Vestimenta
# 28    3/1/2016  Desmond Delaney   Este   Medias Femeninas   Vestimenta
# ..         ...              ...    ...                ...          ...
# 452  31/1/2016       Dustin Gee  Oeste          Caramelos  Comestibles
# 454  31/1/2016       Dustin Gee  Oeste      Limpiavidrios        Hogar
# 456  31/1/2016       Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016       Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016       Dustin Gee  Norte         Escobillón        Hogar
#
#      Unidades Ganancia
# 3           9    14,40
# 4          14     6,72
# 15          5     1,50
# ...

# %%
# TIPOS DE GRAFICOS 
# dataframe.plot()      dataframe.plot(kind='barh')
# dataframe.plot(kind=''bar)   dataframe.plot(kind='scatter')
# dataframe.plot(kind= 'pie')
# Primero  importamos matplotlib.pyplot y lñuego lo ejecutamos
# Antes de todo si el caso es que no lo hemos usado antes ,debemos intalar matplotlib
#!pip install matplotlib

# %%
#Importamos la libreria matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ali = _table[_table.Categoría == 'Comestibles']
ali.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# 5  1/1/2016  Trevor Snodgrass   Este            Cerveza  Comestibles
# 6  1/1/2016    Boris Stanford  Norte          Pepinillo  Comestibles
#
#    Unidades Ganancia
# 1         8     3,84
# 3         9    14,40
# 4        14     6,72
# 5        15     6,00
# 6        14     4,20

# %%
ali.Artículo.value_counts()
# Out:
# Pan                  26
# Chocolate            25
# Sánguche de Queso    25
# Pepinillo            24
# Soda                 19
# Cerveza              17
# Caramelos            17
# Name: Artículo, dtype: int64

# %%
ali.Artículo.value_counts().plot(kind='line');

# %%
ali.Artículo.value_counts().plot(kind='bar');

# %%
ali.Artículo.value_counts().plot(kind='barh');

# %%
ali.Artículo.value_counts().plot(kind='pie');

# %%
_table.plot(kind='scatter', x ='Unidades', y='Ganancia',figsize=(10,30));
